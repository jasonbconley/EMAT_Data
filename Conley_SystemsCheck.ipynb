# %% [markdown]
# # These
# ## Are
# ### Multi-level
# #### Headings

# %% [markdown]
# 1. Python
#     1. Easy
#     2. Packages
#     3. Snakes
# 2. C++
#     1. Hard
#     2. Pointers
#     3. Cpp?
# 3. R
# 4. Java

# %% [markdown]
# ### What I am looking to get out of this class:
# I want to create portfolio objects to help me to get entry into the data science field. What I have learned in the computer science program is really good for background knowledge, my stats minor has helped with data science, but now I want to build some projects to prove that I can be useful to hiring managers.

# %% [markdown]
# ### An image of a cat
# ![sparky.jpeg](attachment:sparky.jpeg)

# %%
# Variables 
x = 20
print(x)
# Out:
# 20

# %%
# Loop
arr = ("This", "is", "a", "loop", "for", "emat")
for str in range(0, len(arr)): 
    print(arr[str], end=" ")
# Out:
# This is a loop for emat

# %%
def func():
    return "Statement"
func()
# Out:
# 'Statement'
